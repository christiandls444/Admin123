# %% [markdown]
# <div style="border-radius:15px;
#             width:100%;
#             background-image: linear-gradient(to bottom right, ##FF007F, #431C53);
#             height: 150px">
# <div style=" color:#fff;
#             height: 400px;
#             margin-left:30px;
#             padding-top:70px;
#             font-size:35px;
#             font-weight: bold;">
#             GRAPHICAL USER INTERFACE
#
# </div>
# </div>

# %%
from tkinter import *
from openpyxl import *
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
from PIL import Image, ImageTk #pip install pillow
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from  nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import naive_bayes
from sklearn.metrics import roc_auc_score
import numpy as np
from collections import OrderedDict
import nltk 
from tkinter import PhotoImage
import webbrowser
from collections import Counter
import sys
from time import sleep
from tkinter import font
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import warnings
warnings.filterwarnings('ignore')
from collections import OrderedDict
import numpy as np 
import pandas as pd 
import os
import nltk
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix
from sklearn.naive_bayes  import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from time import strftime
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg, NavigationToolbar2Tk)
# %pylab
# %matplotlib inline
import csv
from openpyxl import Workbook
import time
from tkinter import filedialog
from spellchecker import SpellChecker
from textblob import Word



#=============================================================================================================
#=============================================================================================================  


class FirstPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)

        
        self.configure(bg="#fff")
        
        load_logout = Image.open("Images/logout.png")
        photo_logout = ImageTk.PhotoImage(load_logout)
        def logout():
            res = messagebox.askquestion('Logout Application', 
                                 'Do you really want to logout')
            if res == 'yes' :
                controller.show_frame(FourthPage) 
        label1 = tk.Label(self, image = photo_logout, bg="#fff", cursor= "hand2")
        label1.image = photo_logout
        label1.place(x = 10, y = 10)
        label1.bind("<Button-1>", lambda e:logout())
        
        def my_time():
            time_string = strftime('Home | %H:%M:%S %p  %A  %x') # time format 
            l1.config(text=time_string)
            l1.after(1000,my_time) # time delay of 1000 milliseconds 
        my_font=('Calibri',16) # display size and style
        l1=tk.Label(self,width=36,font=my_font,bg='#fff',fg='#1a2b57')
        l1.place(x=1120, y=20)  #.grid(row=2,column=5,padx=5,pady=200)
        my_time()
         

            
        def intext():
            controller.show_frame(SecondPage) 
        Labelbg1 = tk.Label(self, width=40, height=34, bg = "#1a2b57", cursor= "hand2")
        Labelbg1.place(x=260, y=200) 
        Labelbg1.bind("<Button-1>", lambda e:intext())
        
        Label3 = tk.Label(self, text="Individual Text Analysis", font=("Calibri", 16, 'bold'),bg = "#1a2b57", fg = "#fff")
        Label3.place(x=295, y=300)
            
        load_intext = Image.open("Images/text_analyze_big.png")
        photo_intext = ImageTk.PhotoImage(load_intext)
        def intext():
            controller.show_frame(SecondPage) 
        label2 = tk.Label(self, image = photo_intext, bg="#1a2b57", cursor= "hand2")
        label2.image = photo_intext
        label2.place(x = 350, y = 400)
        label2.bind("<Button-1>", lambda e:intext())

        def intext():
            controller.show_frame(SecondPage) 
        label2 = tk.Label(self, width=20, height=2, text="Open", font=("Calibri", 16, 'bold'), bg="#1261a0",fg="#fff", cursor= "hand2")
        label2.place(x = 290, y = 600)
        label2.bind("<Button-1>", lambda e:intext())
        
        
        
        def records():
            controller.show_frame(ThirdPage) 
        Labelbg2 = tk.Label(self, width=40, height=34, bg = "#1a2b57", cursor= "hand2")
        Labelbg2.place(x=620, y=200) 
        Labelbg2.bind("<Button-1>", lambda e:records())
        
        Label32 = tk.Label(self, text="Records", font=("Calibri", 16, 'bold'),bg = "#1a2b57", fg = "#fff")
        Label32.place(x=720, y=300)
            
        load_intext = Image.open("Images/records_big.png")
        photo_intext = ImageTk.PhotoImage(load_intext)
        def records():
            controller.show_frame(ThirdPage) 
        label22 = tk.Label(self, image = photo_intext, bg="#1a2b57", cursor= "hand2")
        label22.image = photo_intext
        label22.place(x = 710, y = 400)
        label22.bind("<Button-1>", lambda e:records())

        def records():
            controller.show_frame(ThirdPage) 
        label22 = tk.Label(self, width=20, height=2, text="Open", font=("Calibri", 16, 'bold'), bg="#1261a0",fg="#fff", cursor= "hand2")
        label22.place(x = 650, y = 600)
        label22.bind("<Button-1>", lambda e:records())
        
        
        
        def visualize():
            controller.show_frame(FifthPage) 
        Labelbg3 = tk.Label(self, width=40, height=34, bg = "#1a2b57", cursor= "hand2")
        Labelbg3.place(x=985, y=200) 
        Labelbg3.bind("<Button-1>", lambda e:visualize())
        
        Label33 = tk.Label(self, text="Scatter Plot", font=("Calibri", 16, 'bold'),bg = "#1a2b57", fg = "#fff")
        Label33.place(x=1075, y=300)
            
        load_visualize = Image.open("Images/visualize.png")
        photo_visualize = ImageTk.PhotoImage(load_visualize)
        def visualize():
            controller.show_frame(FifthPage) 
        label23 = tk.Label(self, image = photo_visualize, bg="#1a2b57", cursor= "hand2")
        label23.image = photo_visualize
        label23.place(x = 1080, y = 400)
        label23.bind("<Button-1>", lambda e:visualize())

        def visualize():
            controller.show_frame(FifthPage) 
        label23 = tk.Label(self, width=20, height=2, text="Open", font=("Calibri", 16, 'bold'), bg="#1261a0",fg="#fff", cursor= "hand2")
        label23.place(x = 1015, y = 600)
        label23.bind("<Button-1>", lambda e:visualize())

        
        
        
        
        
        
        

        

 
        
        

                        
#=============================================================================================================
#=============================================================================================================  

class SecondPage(tk.Frame):
            
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.configure(bg="#1a2b57")
        
        
        wb = load_workbook('save.xlsx')
        sheet = wb.active

        def excel():

            # resize the width of columns in
            # excel spreadsheet
            sheet.column_dimensions['A'].width = 25
            sheet.column_dimensions['B'].width = 25
            sheet.column_dimensions['C'].width = 25
            sheet.column_dimensions['D'].width = 25
            sheet.column_dimensions['E'].width = 25
            sheet.column_dimensions['F'].width = 25
            sheet.column_dimensions['G'].width = 25
            sheet.column_dimensions['H'].width = 25
            sheet.column_dimensions['I'].width = 25
            sheet.column_dimensions['J'].width = 25
            sheet.column_dimensions['K'].width = 25
            sheet.column_dimensions['L'].width = 25
            sheet.column_dimensions['M'].width = 25
            sheet.column_dimensions['N'].width = 25
            sheet.column_dimensions['O'].width = 25
            sheet.column_dimensions['P'].width = 25
            sheet.column_dimensions['Q'].width = 70
        
        

            # write given data to an excel spreadsheet
            # at particular location
            sheet.cell(row=1, column=1).value = "Username"
            sheet.cell(row=1, column=2).value = "Text"
            sheet.cell(row=1, column=3).value = "Clean Text"
            sheet.cell(row=1, column=4).value = "Positive"
            sheet.cell(row=1, column=5).value = "Neutral"
            sheet.cell(row=1, column=6).value = "Negative"
            sheet.cell(row=1, column=7).value = "Compound"
            sheet.cell(row=1, column=8).value = "Sentiment"
            sheet.cell(row=1, column=9).value = "Subjectivity"
            sheet.cell(row=1, column=10).value = "Polarity"
            sheet.cell(row=1, column=11).value = "Naive Bayes"
            sheet.cell(row=1, column=12).value = "Decision Tree"
            sheet.cell(row=1, column=13).value = "Random Forest"
            sheet.cell(row=1, column=14).value = "Logistic Regression"
            sheet.cell(row=1, column=15).value = "Support Vector Machine"
            sheet.cell(row=1, column=16).value = "K-Nearest Neighbor"
            sheet.cell(row=1, column=17).value = "Result"
        
        
        
        #load = Image.open("Images/input_text.png")
        #photo = ImageTk.PhotoImage(load)
        #label = tk.Label(self, image = photo)
        #label.image = photo
        #label.place(x = 10, y = 10)
        
        
        def my_time():
            time_string = strftime('Individual Text Analysis | %H:%M:%S %p  %A  %x') # time format 
            l1.config(text=time_string)
            l1.after(1000,my_time) # time delay of 1000 milliseconds 
        my_font=('Calibri',16) # display size and style
        l1=tk.Label(self,width=50,font=my_font,bg='#1a2b57',fg='#fff')
        l1.place(x=970, y=20)  #.grid(row=2,column=5,padx=5,pady=200)
        my_time()
        

        
        
        
        Label2 = tk.Label(self, text="Twitter", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        Label2.place(x=270, y=170)
        
        
        
        load_username = Image.open("Images/username.png")
        photo_username = ImageTk.PhotoImage(load_username)
        Label29 = tk.Label(self,image = photo_username, bg = "#1a2b57")
        Label29.image = photo_username
        Label29.place(x = 350, y = 160)
        
        

        Label28 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label28.place(x=410, y=170)
        
        
        
        
        Label2 = tk.Label(self, text="Input Text", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        Label2.place(x=240, y=250)

        
        
        Label26 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label26.place(x=410, y=250)
        

        
        load_input_text = Image.open("Images/input_text.png")
        photo_input_text = ImageTk.PhotoImage(load_input_text)
        Label = tk.Label(self,image = photo_input_text, bg = "#1a2b57")
        Label.image = photo_input_text
        Label.place(x = 350, y = 240)

        

        
        
        
        load_data_clean = Image.open("Images/data_cleaning.png")
        photo_data_clean = ImageTk.PhotoImage(load_data_clean)
        def data_cleaning():
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp)
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp]  
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))
            #lblTP.config(text = inp) 
            lblTP.insert(10, inp)
        Label5 = tk.Label(self,image = photo_data_clean, bg = "#1a2b57", cursor= "hand2")
        Label5.image = photo_data_clean
        Label5.place(x = 350, y = 320)
        Label5.bind("<Button-1>", lambda e:data_cleaning())
        
        
        
        Label6 = tk.Label(self, text="Data Cleaning", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        Label6.place(x=210, y=330)
        
        
        
        Label7 = tk.Label(self, text="Sentiment Analysis: Vader", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        Label7.place(x=100, y=410)
        

        
        
        
        load_sentiment_analysis = Image.open("Images/sentiment_analysis.png")
        photo_sentiment_analysis = ImageTk.PhotoImage(load_sentiment_analysis)   
        def sentiment_analysis():
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))   
            sid_obj = SentimentIntensityAnalyzer()
            sentiment_dict = sid_obj.polarity_scores(inp)  
            stringneg = str(round(sentiment_dict['neg']*100, 2))
            #lblNEG.config(text = string)
            lblNEG.insert(10, stringneg)
            stringneu = str(round(sentiment_dict['neu']*100, 2))
            #lblNEU.config(text = string)
            lblNEU.insert(10, stringneu)
            stringpos = str(round(sentiment_dict['pos']*100, 2))
            #lblPOS.config(text = string)
            lblPOS.insert(10, stringpos)
            stringcom = str(round(sentiment_dict['compound']*100, 2))
            #lblCOM.config(text = string)
            lblCOM.insert(10, stringcom)
            if sentiment_dict['compound'] >= 0.05:
                stringsa = "1 Positive"
            elif sentiment_dict['compound'] <= -0.05:
                stringsa = "0 Negative"
            else:
                stringsa = "2 Neutral"
            #lblSA.config(text = string)
            lblSA.insert(10, stringsa)
        Label8 = tk.Label(self,image = photo_sentiment_analysis, bg = "#1a2b57", cursor= "hand2")
        Label8.image = photo_sentiment_analysis
        Label8.place(x = 350, y = 400)
        Label8.bind("<Button-1>", lambda e:sentiment_analysis())
        
        
        
        Label9 = tk.Label(self, text="Sentiment Analysis: Textblob", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        Label9.place(x=80, y=490)
        
        
        
        load_textblob = Image.open("Images/textblob.png")
        photo_textblob = ImageTk.PhotoImage(load_textblob)
        def data_textblob():
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp)
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp]  
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp)) 
            sa=TextBlob(inp)
            result=sa.sentiment.polarity
            result=result*100
            rspol= str(round(result,2))
            #lblPOL.config(text = rs)  
            lblPOL.insert(10, rspol)
            result=sa.sentiment.subjectivity
            result=result*100
            rssub= str(round(result,2))
            #lblSO.config(text = rs) 
            lblSO.insert(10, rssub)
        Label10 = tk.Label(self,image = photo_textblob, bg = "#1a2b57", cursor= "hand2")
        Label10.image = photo_textblob
        Label10.place(x = 350, y = 480)
        Label10.bind("<Button-1>", lambda e:data_textblob())
        
        
        
        #Label11 = tk.Label(self, text="ALGORITHM", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        #Label11.place(x=50, y=570)
     
        #options = [
        #    "Naive Bayes",
        #    "Decision Tree",
        #    "Random Forest",
        #    "Logistic Regression",
        #    "Support Vector Machine",
        #    "K-Nearest Neighbor"
        #]
        #oMenuWidth = len(max(options, key=len))
        
        #var = StringVar()
        #var.set( "Algorithm" )
        #wi = OptionMenu(self, var, *options )
        #wi.config(width=oMenuWidth)
        #helv35=font.Font(family='Calibri', size=16)
        #wi.config(font=helv35)
        #wi.config(bg = "#1a2b57", fg = "#f2f2f2", bd=0)
        #wi.place(x=50, y=570)
            

        load_classifier = Image.open("Images/classifier.png")
        photo_classifier = ImageTk.PhotoImage(load_classifier)
        def data_classifier():
            
            messagebox.showinfo("Processing", "Please wait!")
                
            sstart = "Wait for a minutes..."
            lblSTA.insert(10, sstart)
            lblSTA.update_idletasks()
            time.sleep(30)
            
            sstop = "Done"
            lblSTO.insert(10, sstop)
        
            dataset = pd.read_csv('dataset.csv')
            def preprocess(tweet):
                tweet = tweet.lower()
                tweet = re.sub(r'\s+', ' ', tweet).strip()
                tweet = re.sub(r"http\S+|https\S+", "", tweet, flags = re.MULTILINE)
                tweet = BeautifulSoup(tweet, 'lxml').get_text()
                tweet = re.sub('@[A-Za-z0-9]+', '', tweet)
                tweet = re.sub("[^a-zA-Z]", ' ', tweet)
                tweet_tokens = word_tokenize(tweet)
                filtered_words = [word for word in tweet_tokens if word not in stop_words]
                lemmatizer = WordNetLemmatizer()
                lemma_words = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
                lemma_words = [lemmatizer.lemmatize(w, pos = 'n') for w in lemma_words]  
                lemma_words = [lemmatizer.lemmatize(w, pos = 'r') for w in lemma_words]  
                lemma_words = [lemmatizer.lemmatize(w, pos = 'v') for w in lemma_words] 
                return " ".join(lemma_words)
            dataset['pr'] = dataset['text'].apply(lambda x: preprocess(x))
            dataset['two'] = dataset['pr'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
            dataset['dc'] = (dataset['two'].str.split().apply(lambda x: OrderedDict.fromkeys(x).keys()).str.join(' '))
            dataset['ct'] = dataset['dc']
            corpus = []
            for i in range(0, len(dataset)):
                review = re.sub('[^a-zA-Z]', ' ', dataset['ct'][i])
                review = review.lower()
                review = review.split()
                review = ' '.join(review)
                corpus.append(review)
            bow_transformer = CountVectorizer(stop_words='english')
            bow_transformer = bow_transformer.fit(corpus)
            messages_bow = bow_transformer.transform(corpus)
            tfidf_transformer = TfidfTransformer().fit(messages_bow)
            X = tfidf_transformer.transform(messages_bow)
            y = []
            for row in dataset["labeled"]:
                y.append(row)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)
            
            
            
            #naivebayes
            classifier = MultinomialNB()
            classifier.fit(X_train, y_train)
            #lblACC.config( text = nb )
            #lblACC.insert(10, nb)  
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))  
            test_set = [inp]
            new_test = bow_transformer.transform(test_set)
            classifier.predict(new_test)
            nbsrs = classifier.predict(new_test)
            #lblCYC.config(text = rs) 
            lblNBS.insert(10, nbsrs)

                
                
            #decisiontree
            tree = DecisionTreeClassifier()
            tree.fit(X_train, y_train)
            #lblACC.config( text = dt )
            #lblACC.insert(10, dt)
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))  
            test_set = [inp]
            new_test = bow_transformer.transform(test_set)
            tree.predict(new_test)
            dters = tree.predict(new_test)
            #lblCYC.config(text = rs) 
            lblDTE.insert(10, dters)

                
                
            #randomforest
            forest = RandomForestClassifier()
            forest.fit(X_train, y_train)
            #lblACC.config( text = rf )
            #lblACC.insert(10, rf)
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))  
            test_set = [inp]
            new_test = bow_transformer.transform(test_set)
            forest.predict(new_test)
            rftrs = forest.predict(new_test)
            #lblCYC.config(text = rs)
            lblRFT.insert(10, rftrs)

                

            #logisticregression
            lore = LogisticRegression()
            lore.fit(X_train, y_train)
            #lblACC.config( text = lr )
            #lblACC.insert(10, lr)
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))  
            tet_set = [inp]
            new_test = bow_transformer.transform(test_set)
            lore.predict(new_test)
            lrnrs = lore.predict(new_test)
            #lblCYC.config(text = rs) 
            lblLRN.insert(10, lrnrs)
 
                
                
            #supportvectormachine
            sup = SVC()
            sup.fit(X_train, y_train)
            #lblACC.config( text = svm )
            #lblACC.insert(10, svm)
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))  
            test_set = [inp]
            new_test = bow_transformer.transform(test_set)
            sup.predict(new_test)
            svers = sup.predict(new_test)
            #lblCYC.config(text = rs) 
            lblSVE.insert(10, svers)

                

            #knearestneighbors
            kne = KNeighborsClassifier()
            kne.fit(X_train, y_train)
            #lblACC.config( text = knn )
            #lblACC.insert(10, knn)
            inp = input_text.get()
            inp = inp.lower()
            inp = re.sub(r'\s+', ' ', inp).strip()
            inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            inp = BeautifulSoup(inp, 'lxml').get_text()
            inp = re.sub('@[A-Za-z0-9]+', '', inp)
            inp = re.sub("[^a-zA-Z]", ' ', inp) 
            tweet_tokens = word_tokenize(inp)
            filtered_words = [word for word in tweet_tokens if word not in stop_words]
            lemmatizer = WordNetLemmatizer()
            inp = [lemmatizer.lemmatize(w, pos = 'a') for w in filtered_words] 
            inp = [lemmatizer.lemmatize(w, pos = 'n') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'r') for w in inp]  
            inp = [lemmatizer.lemmatize(w, pos = 'v') for w in inp] 
            inp = [x for x in inp if len(x) > 3]
            inp = ' '.join(dict.fromkeys(inp))  
            test_set = [inp]
            new_test = bow_transformer.transform(test_set)
            kne.predict(new_test)
            knrrs = kne.predict(new_test)
            #lblCYC.config(text = rs) 
            lblKNR.insert(10, knrrs)

    
        
            

            
            
                
    
    
    
    
        Label11 = tk.Label(self,image = photo_classifier, bg = "#1a2b57", cursor= "hand2")
        Label11.image = photo_classifier
        Label11.place(x = 350, y = 560)
        Label11.bind("<Button-1>", lambda e:data_classifier())
        
        
        load_result = Image.open("Images/result.png")
        photo_result = ImageTk.PhotoImage(load_result)
        def data_result():
            if (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['cyberbully']" and
               lblSVE.get() == "['cyberbully']" and
               lblKNR.get() == "['cyberbully']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
            elif (lblNBS.get() == "['cyberthreat']" and
               lblDTE.get() == "['cyberthreat']" and
               lblRFT.get() == "['cyberthreat']" and
               lblLRN.get() == "['cyberthreat']" and
               lblSVE.get() == "['cyberthreat']" and
               lblKNR.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
            elif (lblNBS.get() == "['not cybercrime']" and
               lblDTE.get() == "['not cybercrime']" and
               lblRFT.get() == "['not cybercrime']" and
               lblLRN.get() == "['not cybercrime']" and
               lblSVE.get() == "['not cybercrime']" and
               lblKNR.get() == "['not cybercrime']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            ##############################################        
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberthreat']" and
               lblRFT.get() == "['cyberthreat']" and
               lblLRN.get() == "['cyberthreat']" and
               lblSVE.get() == "['cyberthreat']" and
               lblKNR.get() == "['cyberthreat']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                        
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['not cybercrime']" and
               lblRFT.get() == "['not cybercrime']" and
               lblLRN.get() == "['not cybercrime']" and
               lblSVE.get() == "['not cybercrime']" and
               lblKNR.get() == "['not cybercrime']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberthreat']" and
               lblLRN.get() == "['cyberthreat']" and
               lblSVE.get() == "['cyberthreat']" and
               lblKNR.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['not cybercrime']" and
               lblLRN.get() == "['not cybercrime']" and
               lblSVE.get() == "['not cybercrime']" and
               lblKNR.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['cyberthreat']" and
               lblSVE.get() == "['cyberthreat']" and
               lblKNR.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['not cybercrime']" and
               lblSVE.get() == "['not cybercrime']" and
               lblKNR.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['cyberbully']" and
               lblSVE.get() == "['cyberthreat']" and
               lblKNR.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['cyberbully']" and
               lblSVE.get() == "['not cybercrime']" and
               lblKNR.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['cyberbully']" and
               lblSVE.get() == "['cyberbully']" and
               lblKNR.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
            elif (lblNBS.get() == "['cyberbully']" and
               lblDTE.get() == "['cyberbully']" and
               lblRFT.get() == "['cyberbully']" and
               lblLRN.get() == "['cyberbully']" and
               lblSVE.get() == "['cyberbully']" and
               lblKNR.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    
            ##############################################        
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberthreat']" and
                  lblDTE.get() == "['cyberthreat']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']" and
                  lblSVE.get() == "['cyberthreat']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['not cybercrime']" and
                  lblDTE.get() == "['not cybercrime']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']" and
                  lblSVE.get() == "['not cybercrime']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberthreat']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']" and
                  lblSVE.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['not cybercrime']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']" and
                  lblSVE.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            elif (lblKNR.get() == "['cybernulyy']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']" and
                  lblSVE.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']" and
                  lblSVE.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberthreat']" and
                  lblSVE.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['not cybercrime']" and
                  lblSVE.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberbully']" and
                  lblSVE.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
            elif (lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberbully']" and
                  lblSVE.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
 ##############################################        
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberthreat']" and
                  lblNBS.get() == "['cyberthreat']" and
                  lblDTE.get() == "['cyberthreat']" and
                  llblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['not cybercrime']" and
                  lblNBS.get() == "['not cybercrime']" and
                  lblDTE.get() == "['not cybercrime']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberthreat']" and
                  lblDTE.get() == "['cyberthreat']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['not cybercrime']" and
                  lblDTE.get() == "['not cybercrime']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    
            elif (lblSVE.get() == "['cybernulyy']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberthreat']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['not cybercrime']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get()== "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['not cybercrime']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                
        #########################################################################################        
            elif (lblSVE.get() == "['not cybercrime']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                        
            elif (lblSVE.get() == "['not cybercrime']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['not cybercrime']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                        
            elif (lblSVE.get() == "['cyberbully']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberthreat']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                        
            elif (lblSVE.get() == "['cyberthreat']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberthreat']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if int(lblCOM.get()) >= 25 and int(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= 0.10 and int(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) == -0.10 and int(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -25 and int(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                    elif int(lblCOM.get()) >= -100 and int(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully and cyberthreat'
                        lblRES.insert(10, fres)
                        
            elif (lblSVE.get() == "['not cybercrime']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['not cybercrime']" and
                  lblDTE.get() == "['cyberbully']" and
                  lblRFT.get() == "['cyberbully']" and
                  lblLRN.get() == "['cyberbully']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberbully'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberbully'
                        lblRES.insert(10, fres)
                        
                        
            elif (lblSVE.get() == "['not cybercrime']" and
                  lblKNR.get() == "['cyberbully']" and
                  lblNBS.get() == "['cyberthreat']" and
                  lblDTE.get() == "['cyberthreat']" and
                  lblRFT.get() == "['cyberthreat']" and
                  lblLRN.get() == "['cyberthreat']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is cyberthreat'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is cyberthreat'
                        lblRES.insert(10, fres)
            
            elif (lblSVE.get() == "['not cybercrime']" and
                  lblKNR.get() == "['not cybercrime']" and
                  lblNBS.get() == "['cyberbully']" and
                  lblDTE.get() == "['cyberthreat']" and
                  lblRFT.get() == "['not cybercrime']" and
                  lblLRN.get() == "['not cybercrime']"):
                    if float(lblCOM.get()) >= 25 and float(lblCOM.get()) <= 100:
                        fres = 'Base on the evaluation, the cleaned text it shown positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= 0.10 and float(lblCOM.get()) <25:
                        fres = 'Base on the evaluation, the cleaned text it shown semi positive and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) == -0.10 and float(lblCOM.get()) < 0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown neutral and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -25 and float(lblCOM.get()) < -0.10:
                        fres = 'Base on the evaluation, the cleaned text it shown semi negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                    elif float(lblCOM.get()) >= -100 and float(lblCOM.get()) < -25:
                        fres = 'Base on the evaluation, the cleaned text it shown negative and it is not cybercrime'
                        lblRES.insert(10, fres)
                
                
        Labelresult = tk.Label(self,image = photo_result, bg = "#1a2b57", cursor= "hand2")
        Labelresult.image = photo_result
        Labelresult.place(x = 350, y = 800)
        Labelresult.bind("<Button-1>", lambda e:data_result())
  
    
    
    

        Label12 = tk.Label(self, text="Predict what Cybercrime", font=("Calibri", 16),bg = "#1a2b57", fg = "#f2f2f2")
        Label12.place(x=120, y=570)
        
        
        
        Label19 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label19.place(x=410, y=330)
        
        
        
        Label20 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label20.place(x=410, y=410)
        
        
        
        Label21 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label21.place(x=410, y=490)
        
        
        
        Label22 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label22.place(x=410, y=570)
        
        
        
        Label23 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label23.place(x=410, y=650)
        

        Label231 = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label231.place(x=410, y=730)
        
        Label231res = tk.Label(self, width=90, bd=0, font=("Calibri", 19) ,bg = "#263e7c", fg = "#f2f2f2")
        Label231res.place(x=410, y=810)
    
    
        
        
        load_back = Image.open("Images/back.png")
        photo_back = ImageTk.PhotoImage(load_back)
        def back():
            controller.show_frame(FirstPage) 
        labelback = tk.Label(self, image = photo_back, bg="#1a2b57", cursor= "hand2")
        labelback.image = photo_back
        labelback.place(x = 10, y = 10)
        labelback.bind("<Button-1>", lambda e:back())
            
            
 

            
            
        load_data_clear = Image.open("Images/clear.png")
        photo_data_clear = ImageTk.PhotoImage(load_data_clear)
        def clear():
            res = messagebox.askquestion('Clear Inputted', 
                                 'Do you really want to clear')
            
            if res == 'yes' :
                lblUSN.delete(0, END)
                input_text.delete(0, END)
                lblTP.delete(0, END)
                lblPOS.delete(0, END)
                lblNEU.delete(0, END)
                lblNEG.delete(0, END)
                lblCOM.delete(0, END)
                lblSA.delete(0, END)
                lblSO.delete(0, END)
                lblPOL.delete(0, END)
                lblSTA.delete(0, END)
                lblSTO.delete(0, END)
                lblNBS.delete(0, END)
                lblDTE.delete(0, END)
                lblRFT.delete(0, END)
                lblLRN.delete(0, END)
                lblSVE.delete(0, END)
                lblKNR.delete(0, END)
                lblRES.delete(0, END)
        
                #var.set( "Algorithm" )
        Label24 = tk.Label(self,image = photo_data_clear, bg = "#1a2b57", cursor= "hand2")
        Label24.image = photo_data_clear
        Label24.place(x = 570, y = 90)
        Label24.bind("<Button-1>", lambda e:clear())   
        
        
        
        load_save = Image.open("Images/save.png")
        photo_save = ImageTk.PhotoImage(load_save)
        def save():
            res = messagebox.askquestion('Save Application', 
                                 'Do you really want to save')
            
            if res == 'yes' :
                if (lblUSN.get() == "" or
                    input_text.get() == "" or
                    lblTP.get() == "" or
                    lblPOS.get() == "" or
                    lblNEU.get() == "" or
                    lblNEG.get() == "" or
                    lblCOM.get() == "" or
                    lblSA.get() == "" or
                    lblSO.get() == "" or
                    lblPOL.get() == "" or
                    lblNBS.get() == "" or
                    lblDTE.get() == "" or
                    lblRFT.get() == "" or
                    lblLRN.get() == "" or
                    lblSVE.get() == "" or
                    lblKNR.get() == "" or
                    lblRES.get() == ""):
                    messagebox.showinfo("Error", "Please Fill out!")
                else:
                    current_row = sheet.max_row
                    current_column = sheet.max_column
                    # get method returns current text
                    # as string which we write into
                    # excel spreadsheet at particular location
                    sheet.cell(row=current_row + 1, column=1).value = lblUSN.get()
                    sheet.cell(row=current_row + 1, column=2).value = input_text.get()
                    sheet.cell(row=current_row + 1, column=3).value = lblTP.get()
                    sheet.cell(row=current_row + 1, column=4).value = lblPOS.get()
                    sheet.cell(row=current_row + 1, column=5).value = lblNEU.get()
                    sheet.cell(row=current_row + 1, column=6).value = lblNEG.get()
                    sheet.cell(row=current_row + 1, column=7).value = lblCOM.get()
                    sheet.cell(row=current_row + 1, column=8).value = lblSA.get()
                    sheet.cell(row=current_row + 1, column=9).value = lblSO.get()
                    sheet.cell(row=current_row + 1, column=10).value = lblPOL.get()
                    sheet.cell(row=current_row + 1, column=11).value = lblNBS.get()
                    sheet.cell(row=current_row + 1, column=12).value = lblDTE.get()
                    sheet.cell(row=current_row + 1, column=13).value = lblRFT.get()
                    sheet.cell(row=current_row + 1, column=14).value = lblLRN.get()
                    sheet.cell(row=current_row + 1, column=15).value = lblSVE.get()
                    sheet.cell(row=current_row + 1, column=16).value = lblKNR.get()
                    sheet.cell(row=current_row + 1, column=17).value = lblRES.get()
        
                    # save the file
                    wb.save('save.xlsx')
                    clear()
                
        Label25 = tk.Label(self,image = photo_save, bg = "#1a2b57", cursor= "hand2")
        Label25.image = photo_save
        Label25.place(x = 900, y = 90)
        Label25.bind("<Button-1>", lambda e:save())   
            
            
            
           
            
            
            
            
        #def accuracy():  
            #vectorizer = TfidfVectorizer(use_idf=True,strip_accents='ascii')
            #y = cb_df['Labeled']
            #X = vectorizer.fit_transform(cb_df['cb_intermediate_text_preprocessing'])
            #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=None)
            #cb_clf = naive_bayes.MultinomialNB()
            #cb_clf.fit(X_train, y_train)
            #lblAC.config(text = roc_auc_score(y_test, cb_clf.predict_proba(X_test)[:,1]).round(2))
         
        
        
        
        
        
        
            
        #def predict():
            #inp = input_text.get()
            #inp = inp.lower()
            #inp = re.sub(r'\s+', ' ', inp).strip()
            #inp = re.sub(r"http\S+|https\S+", "", inp, flags = re.MULTILINE)
            #inp = BeautifulSoup(inp, 'lxml').get_text()
            #inp = re.sub('@[A-Za-z0-9]+', '', inp)
            #inp = re.sub("[^a-zA-Z]", ' ', inp)      
            #sa=TextBlob(inp)
            #result=sa.sentiment.polarity
            
            #if result > 0:
                #result=result*100
                #rs="Not Cyberbully"
                #lblPR.config(text = rs)
               
            #elif result == 0:
                #result=result*100
                #rs="Not Cyberbully"
                #lblPR.config(text = rs)
               
            #else:
                #result=result*(-1)
                #result=result*100
                #rs="Cyberbully"
                #lblPR.config(text = rs)

            
            
            
            
     
            
        lblUSN = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblUSN.place(x=410, y=170)
            
            
        input_text = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=95)
        input_text.place(x=410, y=250) 

        
        lblTP = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblTP.place(x=410, y=330)
    
    
        Labelpos = tk.Label(self, text="Positive", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelpos.place(x=410, y=370)
        lblPOS = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblPOS.place(x=410, y=410)
        
        
        Labelneut = tk.Label(self, text="Neutral", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelneut.place(x=610, y=370)
        lblNEU = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblNEU.place(x=610, y=410)
        

        Labelneg = tk.Label(self, text="Negative", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelneg.place(x=810, y=370)
        lblNEG = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblNEG.place(x=810, y=410)
        
        
        Labelcom = tk.Label(self, text="Compound", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelcom.place(x=1010, y=370)
        lblCOM = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblCOM.place(x=1010, y=410)
        
        
        Labelsa = tk.Label(self, text="Sentiment", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelsa.place(x=1210, y=370)
        lblSA = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblSA.place(x=1210, y=410)

        
        Labelso = tk.Label(self, text="Subjectivity", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelso.place(x=410, y=450)
        lblSO = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblSO.place(x=410, y=490)
        
        
        Labelpol = tk.Label(self, text="Polarity", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelpol.place(x=610, y=450)
        lblPOL = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblPOL.place(x=610, y=490)

        
        lblSTA = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#ffcc00", bd=0, width=90)
        lblSTA.place(x=410, y=570)
        
        
        lblSTO = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#00ff00", bd=0, width=90)
        lblSTO.place(x=610, y=570)
        
    
        Labelnbs = tk.Label(self, text="Naive Bayes", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelnbs.place(x=410, y=610)
        lblNBS = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblNBS.place(x=410, y=650)
        
        
        Labeldte = tk.Label(self, text="Decision Tree", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labeldte.place(x=810, y=610)
        lblDTE = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblDTE.place(x=810, y=650)
        
        
        Labelrft = tk.Label(self, text="Random Forest", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelrft.place(x=1170, y=610)
        lblRFT = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblRFT.place(x=1170, y=650)
        
        
        Labellrn = tk.Label(self, text="Logistic Regression", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labellrn.place(x=410, y=690)
        lblLRN = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblLRN.place(x=410, y=730)
        
        
        Labelsve = tk.Label(self, text="Support Vector Machine", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelsve.place(x=810, y=690)
        lblSVE = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblSVE.place(x=810, y=730)
        
        
        Labelknr = tk.Label(self, text="K-Nearest Neighbor", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelknr.place(x=1170, y=690)
        lblKNR = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=90)
        lblKNR.place(x=1170, y=730)
        
        
        Labelres = tk.Label(self, text="Result", font=("Calibri", 16),bg = "#1a2b57", fg = "#fff")
        Labelres.place(x=410, y=770)
        lblRES = tk.Entry(self, font=("Calibri", 16),bg="#263e7c", fg="#a0f9a0", bd=0, width=100)
        lblRES.place(x=410, y=810)
        
        

        
        
        
        
        

     

         
        #btnAC = tk.Button(self, text="Accuracy",width=17,height=1, font=("Calibri",16, "bold"),bg="#000",fg="#fff", command = accuracy)
        #btnAC.place(x=1400, y=605)
        
        #btnPR = tk.Button(self, text="Predict",width=17,height=1, font=("Calibri",16, "bold"),bg="#000",fg="#fff", command = predict)
        #btnPR.place(x=1400,y=703)
        
      

        
        
  
        
        #Button = tk.Button(self, text="Back", font=("Arial",15), command=lambda: controller.show_frame(FirstPage))
        #Button.place(x=1100, y=550)
        
 
        


            
        
#=============================================================================================================
#=============================================================================================================  

class ThirdPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.configure(bg="#1a2b57")
        
        def my_time():
            time_string = strftime('Records | %H:%M:%S %p  %A  %x') # time format 
            l1.config(text=time_string)
            l1.after(1000,my_time) # time delay of 1000 milliseconds 
        my_font=('Calibri',16) # display size and style
        l1=tk.Label(self,width=36,font=my_font,bg='#1a2b57',fg='#fff')
        l1.place(x=1110, y=20)  #.grid(row=2,column=5,padx=5,pady=200)
        my_time()
        
        load_back = Image.open("Images/back.png")
        photo_back = ImageTk.PhotoImage(load_back)
        def back():
            controller.show_frame(FirstPage) 
        labelback = tk.Label(self, image = photo_back, bg="#1a2b57", cursor= "hand2")
        labelback.image = photo_back
        labelback.place(x = 10, y = 10)
        labelback.bind("<Button-1>", lambda e:back())
                    
        
        
        
    
    
        # Frame for TreeView
        frame1 = tk.LabelFrame(self, text="Excel Data",bd=0, bg="#1a2b57",fg="#fff",font=("Calibri", 16))
        frame1.place(height=600, width=1250)
        frame1.place(x = 130, y = 100)


        
        
        

        load_load = Image.open("Images/load_files.png")
        photo_load = ImageTk.PhotoImage(load_load)
        Labelload = tk.Label(self,image = photo_load, bg = "#1a2b57", cursor= "hand2")
        Labelload.image = photo_load
        Labelload.place(x = 570, y = 740)
        Labelload.bind("<Button-1>", lambda e:Load_excel_data())   
        
        
        
        load_browse = Image.open("Images/browse_files.png")
        photo_browse = ImageTk.PhotoImage(load_browse)
        Labelbrowse = tk.Label(self,image = photo_browse, bg = "#1a2b57", cursor= "hand2")
        Labelbrowse.image = photo_browse
        Labelbrowse.place(x = 900, y = 740)
        Labelbrowse.bind("<Button-1>", lambda e:File_dialog())   

        
        
        
        # Buttons
        #button1 = tk.Button(file_frame, text="Browse A File", command=lambda: File_dialog())
        #button1.place(rely=0.65, relx=0.50)

        #button2 = tk.Button(file_frame, text="Load File", command=lambda: Load_excel_data())
        #button2.place(rely=0.65, relx=0.30)

        # The file/file path text
        label_file = ttk.Label(self, text="No File Selected", background="#1a2b57",foreground="#fff",font=("Calibri", 16))
        label_file.place(x = 240, y = 98)


        ## Treeview Widget
        tv1 = ttk.Treeview(frame1)
        tv1.place(relheight=1, relwidth=1) # set the height and width of the widget to 100% of its container (frame1).

        treescrolly = tk.Scrollbar(frame1, orient="vertical", command=tv1.yview) # command means update the yaxis view of the widget
        treescrollx = tk.Scrollbar(frame1, orient="horizontal", command=tv1.xview) # command means update the xaxis view of the widget
        tv1.configure(xscrollcommand=treescrollx.set, yscrollcommand=treescrolly.set) # assign the scrollbars to the Treeview Widget
        treescrollx.pack(side="bottom", fill="x") # make the scrollbar fill the x axis of the Treeview widget
        treescrolly.pack(side="right", fill="y") # make the scrollbar fill the y axis of the Treeview widget


        def File_dialog():
            """This Function will open the file explorer and assign the chosen file path to label_file"""
            filename = filedialog.askopenfilename(initialdir="/",
                                                  title="Select A File",
                                                  filetype=(("xlsx files", "*.xlsx"),("All Files", "*.*")))
            label_file["text"] = filename
            return None


        def Load_excel_data():
            """If the file selected is valid this will load the file into the Treeview"""
            file_path = label_file["text"]
            try:
                excel_filename = r"{}".format(file_path)
                if excel_filename[-4:] == ".csv":
                    df = pd.read_csv(excel_filename)
                else:
                    df = pd.read_excel(excel_filename)

            except ValueError:
                tk.messagebox.showerror("Information", "The file you have chosen is invalid")
                return None
            except FileNotFoundError:
                tk.messagebox.showerror("Information", f"No such file as {file_path}")
                return None

            clear_data()
            tv1["column"] = list(df.columns)
            tv1["show"] = "headings"
            for column in tv1["columns"]:
                tv1.heading(column, text=column) # let the column heading = column name

            df_rows = df.to_numpy().tolist() # turns the dataframe into a list of lists
            for row in df_rows:
                tv1.insert("", "end", values=row) # inserts each list into the treeview. For parameters see https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Treeview.insert
            return None


        def clear_data():
            tv1.delete(*tv1.get_children())
            return None

        
#=============================================================================================================
#=============================================================================================================  






class FourthPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.configure(bg="#fff")
        
        Background_side = tk.Label(self, width=3, font=("Calibri", 550), bg="#1a2b57")
        Background_side.place(x=760, y=0)
        
        
#         load = Image.open("Images/exit.png")
#         photo = ImageTk.PhotoImage(load)
#         def close():
#             res = messagebox.askquestion('Exit Application', 
#                                  'Do you really want to exit')
#             if res == 'yes' :
#                 app.destroy() 
#         label = tk.Label(self, image = photo, bg="#fff", cursor= "hand2")
#         label.image = photo
#         label.place(x = 10, y = 10)
#         label.bind("<Button-1>", lambda e:close())
        
        
        
        Lb1 = tk.Label(self, width = 18, font=("Calibri", 30), bg="#fff")
        Lb1.place(x=970, y=300)
        
        L1 = tk.Label(self, text="Username", font=("Calibri", 14), bg="#1a2b57", fg="#fff")
        L1.place(x=970, y=260)
        
        T1 = tk.Entry(self, width=30, bd = 0, font=("Calibri", 16), bg="#fff", fg="#1a2b57")
        T1.place(x=985, y=313)
        
        
        

        Lb2 = tk.Label(self, width = 18, font=("Calibri", 30), bg="#fff")
        Lb2.place(x=970, y=400)
        
        L2 = tk.Label(self, text="Password", font=("Calibri", 14), bg="#1a2b57", fg="#fff")
        L2.place(x=970, y=360)
        
        sv = tk.StringVar()
        e1_str=tk.StringVar()
        T2 = tk.Entry(self, width=30, show="*", textvariable=e1_str, bd = 0, font=("Calibri", 16), bg="#fff", fg="#1a2b57")
        T2.place(x=985, y=413)
        
        def verify():    
            if T1.get() == 'Admin123' and T2.get() == 'Admin123':
                controller.show_frame(FirstPage)
            else:
                messagebox.showinfo("Error", "Please provide correct username and password!!")
    
                
                
        B1 = tk.Button(self, width =33,text="SIGN IN", bg = "#1261a0", fg = "#fff", font=("Calibri",16), command=verify, bd=0)
        B1.place(x=970, y=500)
    
        
        
        c_v1=IntVar(value=0) 
        
        def my_show():
            if(c_v1.get()==1):
                T2.config(show='')
            else:
                T2.config(show='*')
        
        c1 = tk.Checkbutton(self,variable=c_v1,onvalue=1,offvalue=0,command=my_show, bg="#1a2b57",fg="#1a2b57")
        c1.place(x=965, y=463) 
        
        sh = tk.Label(self, text="Show Password", font=("Calibri", 14), bg="#1a2b57", fg="#fff")
        sh.place(x=990, y=460)
        

        
        
#         load_ml = Image.open("Images/ml.png")
#         photo_ml = ImageTk.PhotoImage(load_ml)
#         Labelimg = tk.Label(self,image = photo_ml, bg = "#fff")
#         Labelimg.image = photo_ml
#         Labelimg.place(x = 330, y = 230)
        
        
#         tit1 = tk.Label(self, text="A FRAMEWORK TO PREDICT", font=("Calibri", 20,'bold'), bg="#fff", fg="#1a2b57")
#         tit1.place(x=220, y=360)
        
#         tit2 = tk.Label(self, text="CYBERBULLY AND CYBERTHREAT", font=("Calibri", 20,'bold'), bg="#fff", fg="#1a2b57")
#         tit2.place(x=195, y=410)
        
#         tit3 = tk.Label(self, text="USING NATURAL LANGUAGE PROCESSING", font=("Calibri", 20,'bold'), bg="#fff", fg="#1a2b57")
#         tit3.place(x=135, y=460)
        
#         tit4 = tk.Label(self, text="AND MACHINE LEARNING", font=("Calibri", 20,'bold'), bg="#fff", fg="#1a2b57")
#         tit4.place(x=225, y=510)
        
        
        
        
        
#=============================================================================================================
#=============================================================================================================  






#=============================================================================================================
#=============================================================================================================  

class FifthPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.configure(bg="#1a2b57")
        
        
        def my_time():
            time_string = strftime('Scatter Plot | %H:%M:%S %p  %A  %x') # time format 
            l1.config(text=time_string)
            l1.after(940,my_time) # time delay of 1000 milliseconds 
        my_font=('Calibri',16) # display size and style
        l1=tk.Label(self,width=50,font=my_font,bg='#1a2b57',fg='#fff')
        l1.place(x=1020, y=20)  #.grid(row=2,column=5,padx=5,pady=200)
        my_time()
        
        
        load_back = Image.open("Images/back.png")
        photo_back = ImageTk.PhotoImage(load_back)
        def back():
            controller.show_frame(FirstPage) 
        labelback = tk.Label(self, image = photo_back, bg="#1a2b57", cursor= "hand2")
        labelback.image = photo_back
        labelback.place(x = 10, y = 10)
        labelback.bind("<Button-1>", lambda e:back())
        
        

        

        

        
        
        #def graphnato():
            # the figure that will contain the plot
            #fig = Figure(figsize = (5, 5),
                         #dpi = 100)
            # list of squares
            #y = [i**2 for i in range(101)]
            # adding the subplot
            #plot1 = fig.add_subplot(111)
            # plotting the graph
            #plot1.plot(y)
            # creating the Tkinter canvas
            # containing the Matplotlib figure
            #canvas = FigureCanvasTkAgg(fig, master = self)  
            #canvas.draw()
            # placing the canvas on the Tkinter window
            #canvas.get_tk_widget().pack()
            # creating the Matplotlib toolbar
            #toolbar = NavigationToolbar2Tk(canvas, self)
            #toolbar.update()
            # placing the toolbar on the Tkinter window
            #canvas.get_tk_widget().pack()
        #Button3 = tk.Button(self, text="Graph", font=("Arial",15), command=graphnato)
        #Button3.place(x=500, y=500)
        
        
        figure = Figure(figsize=(7, 7), dpi=100)
        ax = figure.add_subplot(111)

        
 
        
        load_graph_it = Image.open("Images/graph_it.png")
        photo_graph_it = ImageTk.PhotoImage(load_graph_it)
        def graph_it():
            #x = np.random.rand(1, 10)
            #y = np.random.rand(1, 10)
            #ax.scatter(x, y)
            dataset = pd.read_excel('save.xlsx')
            cv = CountVectorizer(stop_words = 'english')
            words = cv.fit_transform(dataset['Clean Text'])
            sum_words = words.sum(axis=0)
            words_freq = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
            words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
            frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])
            words_df = pd.DataFrame(frequency)
            def get_sub(Tweets):
                return TextBlob(Tweets).sentiment.subjectivity
            def get_pol(Tweets):
                return TextBlob(Tweets).sentiment.polarity
            words_df['subjectivity'] = words_df['word'].apply(get_sub)
            words_df['polarity'] = words_df['word'].apply(get_pol)      
            for i in range(0, words_df.shape[0]):
                ax.scatter(words_df['polarity'][i], words_df['subjectivity'][i], color="blue")   
            canvas.draw()
            
            


        
        canvas = FigureCanvasTkAgg(figure, self)
        canvas.draw()
        canvas.get_tk_widget().place(x=410, y=100)
        toolbar = NavigationToolbar2Tk(canvas, self)
        toolbar.update()
        toolbar.place(x=410, y=760)
        canvas.get_tk_widget()
        
        
        

        
        
        

        
        labelgraph_it = tk.Label(self, image = photo_graph_it, bg="#1a2b57", cursor= "hand2")
        labelgraph_it.image = photo_graph_it
        labelgraph_it.place(x = 1130, y = 100)
        labelgraph_it.bind("<Button-1>", lambda e:graph_it())
        
        
        

        
        
        
        
    
        
        
#=============================================================================================================
#=============================================================================================================  



class Application(tk.Tk):
    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        
        #creating a windows
        windows = tk.Frame(self)
        windows.pack()
        
        windows.grid_rowconfigure(0, minsize=900)
        windows.grid_columnconfigure(0, minsize=1545)
        
        self.frames = {}
        for F in (FirstPage, SecondPage, ThirdPage, FourthPage, FifthPage):
            frame = F(windows, self)
            self.frames[F] = frame
            frame.grid(row=0, column=0, sticky="nsew")
            
        self.show_frame(FourthPage)
        
    def show_frame(self, page):
        frame = self.frames[page]
        frame.tkraise()
        self.title("Application")
        self.attributes('-fullscreen', True)
    
     
     
    
        
        #load = Image.open("Images/exit.png")
        #photo = ImageTk.PhotoImage(load)
        #def close():
            #res = messagebox.askquestion('Exit Application', 
            #                     'Do you really want to exit')
            #if res == 'yes' :
            #  app.destroy() 
        #labe3l = tk.Label(self, image = photo, bg="#1a2b57", cursor= "hand2")
        #label.image = photo
        #label.place(x = 1460, y = 10)
        #label.bind("<Button-1>", lambda e:close())
        
        
        
        
        
        
        
        

        #def my_time():
            #time_string = strftime('%H:%M:%S %p  %A  %x') # time format 
            #l1.config(text=time_string)
            #l1.after(1000,my_time) # time delay of 1000 milliseconds 
        #my_font=('Calibri',16) # display size and style
        #l1=tk.Label(self,width=26,font=my_font,bg='#1a2b57',fg='#f2f2f2')
        #l1.place(x=1160, y=20)  #.grid(row=2,column=5,padx=5,pady=200)
        #my_time()
  
        

   
        
     
        

    
            
app = Application()
app.maxsize(1545, 900)
app.mainloop()
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
